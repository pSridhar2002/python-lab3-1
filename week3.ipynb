# %%
lst=[1,4,5]
lst2 =[1,5,4]
print(id(lst))
print(id(lst2))
print(sorted(lst)," ",id(lst))
print(sorted(lst2)," ",id(lst2))
# Out:
# 140281059210416
# 140281059736304
# [1, 4, 5]   140281059210416
# [1, 4, 5]   140281059736304

# %%
list1=eval(input("enter a list1"))
list2=eval(input("enter a list2"))
if(len(list1)==len(list2)):
  if(sorted(list1)==sorted(list2)):
    print("True")
    print(id(list1),id(list2))
  else:
    print("false")
else:
  print("false")
# Out:
# enter a list11,3,4
# enter a list23,4,5
# false

# %%
st=input("enter a string")
if(st==st[: :-1]):
  print("true")
else:
  print("false")
# Out:
# enter a stringsrirs
# true

# %%
def fact(n):
  if n==0 or n==1:
    return 1
  else:
    return n*fact(n-1)
x=int(input("enter a number"))
print("factorial of %d is %d"%(x,fact(x)))
# Out:
# enter a number6
# factorial of 6 is 720

# %%
def takeip():lst=eval(input("enter a list"))
  a,b = [int(i) for i in input("enter a 2 numbers").split(',')]
  return a,b
def add(a,b):
  return a+b
def sub(a,b):
  return a-b
def div(a,b):
  return a/b
def mul(a,b):
  return a*b
def pow(a,b):
  return a**b
print("MENU")
print("1. add \n 2. Sub\n 3. Mul \n 4.div \n 5.pow \n")
while True:
  ch=eval(input('enter a input'))
  if ch==1:
    a,b=takeip()
    print("Add :=",add(a,b))
  if ch==2:
    a,b=takeip()
    print("Sub :=",sub(a,b))
  if ch==3:
    a,b=takeip()
    print("Mul  :=", Sub\n 3. Mul \n 4.div \n 5.pow \n")
while True:
  ch=eval(input('enter a input'))
  if ch==1:
    a,b=takeip()
    print("Add :=",add(a,b))
  if ch==2:
    a,b=takeip()
    print("Sub :="mul(a,b))
  if ch==4:
    a,b=takeip()
    print("div :=",div(a,b))
  if ch==5:
    a,b=takeip()
    print("pow :=",pow(a,b))
  if ch not in [1,2,3,4,5]:
    print("enter a valid choice")
    break
# Out:
# MENU
# 1. add
#  2. Sub
#  3. Mul
#  4.div
#  5.pow
#
# enter a input2
# enter a 2 numbers9,7
# Sub := 2
# enter a input1
# enter a 2 numbers3,7
# Add := 10
# enter a input8
# enter a valid choice =

# %%
st="pyhton"
st1="pyhton"
print(id(st)," ",id(st1))
# Out:
# 140281058946672   140281058946672

# %%
#check list is empty or not
# take input frpm keyboard
# 2= python program --- which checks how many suffixs are equal in a given list

# %%
# 1==
for _ in range(3):
  print(" hhh")
# Out:
#  hhh
#  hhh
#  hhh

# %%
lst=eval(input("enter a list"))
if len(lst):
  print("not empty")
else:
  print("empty")
print({1,3,5}^{1,3})
# Out:
# enter a list[]
# empty
# {5}

# %%
lst=eval(input("enter a list"))
for i in range(len(lst)):
  if
# Out:
# enter a list["456","212"]
# have common:
# have common:
